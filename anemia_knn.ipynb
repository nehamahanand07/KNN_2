# %%
#https://www.kaggle.com/datasets/ehababoelnaga/anemia-types-classification

import pandas as pd
import numpy as np
df=pd.read_csv('anemia.csv')
df
# Out:
#         WBC    LYMp   NEUTp     LYMn    NEUTn   RBC   HGB       HCT   MCV  \
# 0     10.00  43.200  50.100  4.30000  5.00000  2.77   7.3   24.2000  87.7
# 1     10.00  42.400  52.300  4.20000  5.30000  2.84   7.3   25.0000  88.2
# 2      7.20  30.700  60.700  2.20000  4.40000  3.97   9.0   30.5000  77.0
# 3      6.00  30.200  63.500  1.80000  3.80000  4.22   3.8   32.8000  77.9
# 4      4.20  39.100  53.700  1.60000  2.30000  3.93   0.4  316.0000  80.6
# ...     ...     ...     ...      ...      ...   ...   ...       ...   ...
# 1276   4.40  25.845  77.511  1.88076  5.14094  4.86  13.5   46.1526  80.7
# 1277   5.60  25.845  77.511  1.88076  5.14094  4.85  15.0   46.1526  91.7
# 1278   9.20  25.845  77.511  1.88076  5.14094  4.47  13.1   46.1526  88.7
# 1279   6.48  25.845  77.511  1.88076  5.14094  4.75  13.2   46.1526  86.7
# 1280   8.80  25.845  77.511  1.88076  5.14094  4.95  15.2   46.1526  89.7
#
#        MCH  MCHC    PLT        PDW      PCT                      Diagnosis
# ...

# %%
df.columns
# Out:
# Index(['WBC', 'LYMp', 'NEUTp', 'LYMn', 'NEUTn', 'RBC', 'HGB', 'HCT', 'MCV',
#        'MCH', 'MCHC', 'PLT', 'PDW', 'PCT', 'Diagnosis'],
#       dtype='object')

# %%
df.shape
# Out:
# (1281, 15)

# %%
df.dtypes
# Out:
# WBC          float64
# LYMp         float64
# NEUTp        float64
# LYMn         float64
# NEUTn        float64
# RBC          float64
# HGB          float64
# HCT          float64
# MCV          float64
# MCH          float64
# MCHC         float64
# PLT          float64
# PDW          float64
# PCT          float64
# Diagnosis     object
# dtype: object

# %%
#missing value checking
df.isna().sum()
# Out:
# WBC          0
# LYMp         0
# NEUTp        0
# LYMn         0
# NEUTn        0
# RBC          0
# HGB          0
# HCT          0
# MCV          0
# MCH          0
# MCHC         0
# PLT          0
# PDW          0
# PCT          0
# Diagnosis    0
# dtype: int64

# %%
#x and y separating as arrays
x=df.iloc[:,:-1].values
x
# Out:
# array([[1.00000000e+01, 4.32000000e+01, 5.01000000e+01, ...,
#         1.89000000e+02, 1.25000000e+01, 1.70000000e-01],
#        [1.00000000e+01, 4.24000000e+01, 5.23000000e+01, ...,
#         1.80000000e+02, 1.25000000e+01, 1.60000000e-01],
#        [7.20000000e+00, 3.07000000e+01, 6.07000000e+01, ...,
#         1.48000000e+02, 1.43000000e+01, 1.40000000e-01],
#        ...,
#        [9.20000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         3.29000000e+02, 1.43125116e+01, 2.60280000e-01],
#        [6.48000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         1.74000000e+02, 1.43125116e+01, 2.60280000e-01],
#        [8.80000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         2.79000000e+02, 1.43125116e+01, 2.60280000e-01]], shape=(1281, 14))

# %%
y=df.iloc[:,-1].values
y
# Out:
# array(['Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Iron deficiency anemia', ..., 'Healthy', 'Healthy', 'Healthy'],
#       shape=(1281,), dtype=object)

# %%
x.ndim
# Out:
# 2

# %%
y.ndim
# Out:
# 1

# %%
#converting training and testing data
from sklearn.model_selection import train_test_split
x_test,x_train,y_test,y_train=train_test_split(x,y,test_size=0.30,random_state=42)

# %%
x_test
# Out:
# array([[8.00000000e+00, 2.82000000e+01, 6.38000000e+01, ...,
#         1.73000000e+02, 1.54000000e+01, 1.70000000e-01],
#        [4.50000000e+00, 2.43000000e+01, 6.65000000e+01, ...,
#         8.50000000e+01, 1.67000000e+01, 9.00000000e-02],
#        [3.92000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         2.29000000e+02, 1.43125116e+01, 2.60280000e-01],
#        ...,
#        [1.03100000e+01, 2.58450000e+01, 7.75110000e+01, ...,
#         1.79000000e+02, 1.43125116e+01, 2.60280000e-01],
#        [5.90000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         2.00000000e+02, 1.33000000e+01, 2.60280000e-01],
#        [9.09000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         2.30000000e+02, 1.43125116e+01, 2.60280000e-01]], shape=(896, 14))

# %%
x_train
# Out:
# array([[7.60000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         1.56000000e+02, 1.43125116e+01, 2.60280000e-01],
#        [8.50000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         3.80000000e+02, 1.31000000e+01, 2.60280000e-01],
#        [9.20000000e+00, 2.58450000e+01, 7.75110000e+01, ...,
#         1.40000000e+02, 1.43125116e+01, 2.60280000e-01],
#        ...,
#        [9.00000000e+00, 1.69000000e+01, 7.21000000e+01, ...,
#         2.31000000e+02, 1.40000000e+01, 2.30000000e-01],
#        [4.20000000e+00, 3.13000000e+01, 6.06000000e+01, ...,
#         1.46000000e+02, 1.25000000e+01, 1.30000000e-01],
#        [1.33500000e+01, 2.58450000e+01, 7.75110000e+01, ...,
#         3.73000000e+02, 1.43125116e+01, 2.60280000e-01]], shape=(385, 14))

# %%
y_train
# Out:
# array(['Normocytic normochromic anemia', 'Healthy',
#        'Normocytic normochromic anemia', 'Other microcytic anemia',
#        'Normocytic normochromic anemia', 'Healthy',
#        'Iron deficiency anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Healthy', 'Leukemia', 'Leukemia with thrombocytopenia', 'Healthy',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Iron deficiency anemia', 'Iron deficiency anemia', 'Healthy',
#        'Healthy', 'Normocytic normochromic anemia', 'Healthy', 'Healthy',
#        'Thrombocytopenia', 'Normocytic normochromic anemia', 'Healthy',
#        'Other microcytic anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Healthy', 'Healthy',
#        'Normocytic hypochromic anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic normochromic anemia',
# ...

# %%
y_test
# Out:
# array(['Healthy', 'Normocytic hypochromic anemia', 'Healthy',
#        'Normocytic normochromic anemia', 'Normocytic normochromic anemia',
#        'Healthy', 'Normocytic normochromic anemia',
#        'Other microcytic anemia', 'Iron deficiency anemia',
#        'Normocytic hypochromic anemia', 'Iron deficiency anemia',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Iron deficiency anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Healthy', 'Normocytic hypochromic anemia', 'Healthy', 'Healthy',
#        'Other microcytic anemia', 'Normocytic hypochromic anemia',
#        'Normocytic normochromic anemia', 'Healthy', 'Healthy', 'Healthy',
#        'Leukemia', 'Normocytic normochromic anemia',
#        'Iron deficiency anemia', 'Healthy', 'Iron deficiency anemia',
# ...

# %%
#normalizing
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(x_train)
x_train=scaler.transform(x_train)
x_test=scaler.transform(x_test)

# %%
x_train
# Out:
# array([[ 0.04497911, -0.05062771,  0.54091986, ..., -0.7727027 ,
#          0.04125221,  0.67632049],
#        [ 0.3343453 , -0.05062771,  0.54091986, ...,  1.62778869,
#         -0.61201973,  0.67632049],
#        [ 0.55940789, -0.05062771,  0.54091986, ..., -0.94416638,
#          0.04125221,  0.67632049],
#        ...,
#        [ 0.49510429, -1.37479405, -0.05294931, ...,  0.03103325,
#         -0.12712147,  0.1780364 ],
#        [-1.04818204,  0.7568991 , -1.31509965, ..., -0.8798675 ,
#         -0.93528524, -1.46755175],
#        [ 1.89370753, -0.05062771,  0.54091986, ...,  1.55277334,
#          0.04125221,  0.67632049]], shape=(385, 14))

# %%
x_test
# Out:
# array([[ 0.17358631,  0.29799294, -0.9638926 , ..., -0.59052255,
#          0.62716471, -0.80931649],
#        [-0.95172664, -0.27934062, -0.66756165, ..., -1.53357275,
#          1.3275733 , -2.12578701],
#        [-1.13820708, -0.05062771,  0.54091986, ...,  0.0096003 ,
#          0.04125221,  0.67632049],
#        ...,
#        [ 0.91629286, -0.05062771,  0.54091986, ..., -0.52622368,
#          0.04125221,  0.67632049],
#        [-0.50160146, -0.05062771,  0.54091986, ..., -0.30117761,
#         -0.50426457,  0.67632049],
#        [ 0.52404091, -0.05062771,  0.54091986, ...,  0.02031677,
#          0.04125221,  0.67632049]], shape=(896, 14))

# %%
#algorithm implementation
from sklearn.neighbors import KNeighborsClassifier
knn_model=KNeighborsClassifier(n_neighbors=7)
knn_model.fit(x_train,y_train)
y_pred=knn_model.predict(x_test)
y_pred
# Out:
# array(['Healthy', 'Normocytic hypochromic anemia', 'Healthy',
#        'Normocytic normochromic anemia', 'Normocytic normochromic anemia',
#        'Normocytic normochromic anemia', 'Normocytic normochromic anemia',
#        'Iron deficiency anemia', 'Iron deficiency anemia',
#        'Normocytic hypochromic anemia', 'Iron deficiency anemia',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Normocytic normochromic anemia', 'Normocytic hypochromic anemia',
#        'Healthy', 'Normocytic normochromic anemia',
#        'Normocytic normochromic anemia', 'Normocytic hypochromic anemia',
#        'Normocytic normochromic anemia', 'Healthy', 'Healthy', 'Healthy',
#        'Healthy', 'Normocytic normochromic anemia',
# ...

# %%
y_test
# Out:
# array(['Healthy', 'Normocytic hypochromic anemia', 'Healthy',
#        'Normocytic normochromic anemia', 'Normocytic normochromic anemia',
#        'Healthy', 'Normocytic normochromic anemia',
#        'Other microcytic anemia', 'Iron deficiency anemia',
#        'Normocytic hypochromic anemia', 'Iron deficiency anemia',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Iron deficiency anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Healthy', 'Normocytic hypochromic anemia', 'Healthy', 'Healthy',
#        'Other microcytic anemia', 'Normocytic hypochromic anemia',
#        'Normocytic normochromic anemia', 'Healthy', 'Healthy', 'Healthy',
#        'Leukemia', 'Normocytic normochromic anemia',
#        'Iron deficiency anemia', 'Healthy', 'Iron deficiency anemia',
# ...

# %%
print(knn_model.predict(scaler.transform([[5.6,30.1,1.8,4,4,3.9,4.1,11,45,89,24,145,12.5,0.26]])))
# Out:
# ['Iron deficiency anemia']

# %%
#confusion matrix
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
cm
# Out:
# array([[190,   0,   0,   0,   0,   7,  14,   0,   5],
#        [  8,  67,   0,   1,   0,  54,   3,   4,   0],
#        [ 18,   1,  14,   0,   0,   2,   2,   0,   0],
#        [  3,   1,   0,   1,   0,   0,   1,   0,   2],
#        [  0,   0,   0,   0,   1,  11,   4,   0,   0],
#        [ 16,   8,   3,   2,   0, 136,  18,   6,   2],
#        [ 11,   1,   0,   0,   0,  18, 170,   0,   0],
#        [  4,   5,   0,   0,   0,   7,   6,  18,   2],
#        [ 16,   0,   0,   0,   0,   6,   6,   0,  21]])

# %%
t=df['Diagnosis'].unique()
t
# Out:
# array(['Normocytic hypochromic anemia', 'Iron deficiency anemia',
#        'Other microcytic anemia', 'Leukemia', 'Healthy',
#        'Thrombocytopenia', 'Normocytic normochromic anemia',
#        'Leukemia with thrombocytopenia', 'Macrocytic anemia'],
#       dtype=object)

# %%
y_train
# Out:
# array(['Normocytic normochromic anemia', 'Healthy',
#        'Normocytic normochromic anemia', 'Other microcytic anemia',
#        'Normocytic normochromic anemia', 'Healthy',
#        'Iron deficiency anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Healthy', 'Leukemia', 'Leukemia with thrombocytopenia', 'Healthy',
#        'Normocytic hypochromic anemia', 'Normocytic hypochromic anemia',
#        'Iron deficiency anemia', 'Iron deficiency anemia', 'Healthy',
#        'Healthy', 'Normocytic normochromic anemia', 'Healthy', 'Healthy',
#        'Thrombocytopenia', 'Normocytic normochromic anemia', 'Healthy',
#        'Other microcytic anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Healthy', 'Healthy',
#        'Normocytic hypochromic anemia', 'Normocytic normochromic anemia',
#        'Normocytic hypochromic anemia', 'Normocytic normochromic anemia',
# ...

# %%
#displaying confusion matrix
#labels order check from y_train

from sklearn.metrics import ConfusionMatrixDisplay
labels=['Normocytic normochromic anemia','Healthy','Other microcytic anemia','Normocytic hypochromic anemia','Macrocytic anemia','Iron deficiency anemia','Thrombocytopenia',
        'Leukemia','Leukemia with thrombocytopenia']
cmd=ConfusionMatrixDisplay(cm,display_labels=labels)
cmd.plot()

# %%
#accuracy score
from sklearn.metrics import accuracy_score
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.6897321428571429

# %%
#STEP : CLASSIFICATION REPORT based on training and testing data , not entire data
from sklearn.metrics import classification_report
cr=classification_report(y_test,y_pred)
print(cr)
# Out:
#                                 precision    recall  f1-score   support
#
#                        Healthy       0.71      0.88      0.79       216
#         Iron deficiency anemia       0.81      0.49      0.61       137
#                       Leukemia       0.82      0.38      0.52        37
# Leukemia with thrombocytopenia       0.25      0.12      0.17         8
#              Macrocytic anemia       1.00      0.06      0.12        16
#  Normocytic hypochromic anemia       0.56      0.71      0.63       191
# Normocytic normochromic anemia       0.76      0.85      0.80       200
#        Other microcytic anemia       0.64      0.43      0.51        42
#               Thrombocytopenia       0.66      0.43      0.52        49
#
#                       accuracy                           0.69       896
#                      macro avg       0.69      0.48      0.52       896
#                   weighted avg       0.71      0.69      0.67       896
